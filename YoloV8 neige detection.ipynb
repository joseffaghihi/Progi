# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.8/611.8 kB 9.5 MB/s eta 0:00:00
# ...

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.157 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# Setup complete ✅ (4 CPUs, 25.5 GB RAM, 26.3/166.8 GB disk)

# %%
from ultralytics import YOLO

# %%
ROOT_DIR = '/content/drive/MyDrive/Yolov8/train_yolov8_customdataset/google_colab'

# %%
import os

# Load a model
model = YOLO("yolov8m.yaml")  # build a new model
model = YOLO("yolov8m.pt")  # load a pretrained model

# Use the model
results = model.train(data=os.path.join(ROOT_DIR, "google_colab_neige_config.yaml"), epochs=30)  # train the model
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1      1392  ultralytics.nn.modules.conv.Conv             [3, 48, 3, 2]
#   1                  -1  1     41664  ultralytics.nn.modules.conv.Conv             [48, 96, 3, 2]
#   2                  -1  2    111360  ultralytics.nn.modules.block.C2f             [96, 96, 2, True]
#   3                  -1  1    166272  ultralytics.nn.modules.conv.Conv             [96, 192, 3, 2]
#   4                  -1  4    813312  ultralytics.nn.modules.block.C2f             [192, 192, 4, True]
#   5                  -1  1    664320  ultralytics.nn.modules.conv.Conv             [192, 384, 3, 2]
#   6                  -1  4   3248640  ultralytics.nn.modules.block.C2f             [384, 384, 4, True]
#   7                  -1  1   1991808  ultralytics.nn.modules.conv.Conv             [384, 576, 3, 2]
# ...

# %%
import locale
def getpreferredencoding(do_setlocale = True):
    return "UTF-8"
locale.getpreferredencoding = getpreferredencoding

# %%
# !scp -r /content/runs '/content/drive/MyDrive/Yolov8'

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/Yolov8/runs/detect/train/weights/best.pt conf=0.55 source=/content/drive/MyDrive/Yolov8/Testing_car_neige
# Out:
# Ultralytics YOLOv8.0.157 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# Model summary (fused): 218 layers, 25840339 parameters, 0 gradients
#
# image 1/12 /content/drive/MyDrive/Yolov8/Testing_car_neige/5cc08c19-0159-459b-a29d-a8a688cb0565.jpeg: 384x640 1 Neige, 79.3ms
# image 2/12 /content/drive/MyDrive/Yolov8/Testing_car_neige/Audi_S6_Sedan_2011_9.jpg: 352x640 (no detections), 57.5ms
# image 3/12 /content/drive/MyDrive/Yolov8/Testing_car_neige/Bentley_Continental_GT_Coupe_2012_15.jpg: 416x640 (no detections), 55.5ms
# image 4/12 /content/drive/MyDrive/Yolov8/Testing_car_neige/Bentley_Continental_GT_Coupe_2012_18.jpg: 352x640 1 Neige, 8.3ms
# image 5/12 /content/drive/MyDrive/Yolov8/Testing_car_neige/Bentley_Continental_GT_Coupe_2012_22.jpg: 480x640 (no detections), 55.6ms
# image 6/12 /content/drive/MyDrive/Yolov8/Testing_car_neige/enterré-7945611.jpeg: 416x640 1 Neige, 7.9ms
# ...

# %%
# !scp -r /content/runs '/content/drive/MyDrive/Yolov8'
